# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('C:/Users/cyphe/Downloads/iris_data.csv')
df
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df[df.isnull().any(axis=1)]
# Out:
#     Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 12           4.8          NaN           NaN          0.1  setosa

# %%
df.iloc[12]
# Out:
# Sepal.Length       4.8
# Sepal.Width        NaN
# Petal.Length       NaN
# Petal.Width        0.1
# Species         setosa
# Name: 12, dtype: object

# %%
df.groupby('Species').agg(['mean', 'median'])
# Out:
#            Sepal.Length        Sepal.Width        Petal.Length         \
#                    mean median        mean median         mean median
# Species
# setosa           15.698    5.0    3.436735    3.4     1.463265   1.50
# versicolor        5.936    5.9    2.770000    2.8     4.260000   4.35
# virginica         6.588    6.5    2.974000    3.0     5.552000   5.55
#
#            Petal.Width
#                   mean median
# Species
# setosa           0.246    0.2
# versicolor       1.326    1.3
# virginica        2.026    2.0

# %%
df.at[12,'Sepal.Width'] = 3.4
df.at[12,'Petal.Length'] = 1.5

# %%
df.iloc[12]
# Out:
# Sepal.Length       4.8
# Sepal.Width        3.4
# Petal.Length       1.5
# Petal.Width        0.1
# Species         setosa
# Name: 12, dtype: object

# %%
fig, ax = plt.subplots()
fig.set_size_inches(8, 6)
sns.boxplot(x='Species', y = 'Sepal.Length', data=df)
# Out:
# <AxesSubplot:xlabel='Species', ylabel='Sepal.Length'>

# %% [markdown]
# ## Pair plots to visualise 4D

# %%
df = df.loc[df['Sepal.Length'] != 540]

# %%
sns.set_style('whitegrid')
sns.pairplot(df,hue='Species',height=2.7)
plt.show()

# %%
iris_setosa = df.loc[df['Species']=='Setosa']

# %% [markdown]
# ## Univariate Analysis on Petal Length

# %%
# PDF check for dataset overlap
sns.FacetGrid(df, hue='Species',height=6)\
    .map(sns.distplot,"Petal.Length")\
    .add_legend()
# Out:
# C:\JupyterLab\resources\jlab_server\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\JupyterLab\resources\jlab_server\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# PDF check for dataset overlap
sns.FacetGrid(df, hue='Species',height=6)\
    .map(sns.distplot,"Petal.Width")\
    .add_legend()
# Out:
# C:\JupyterLab\resources\jlab_server\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\JupyterLab\resources\jlab_server\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
fig, ax = plt.subplots()
fig.set_size_inches(8, 6)
sns.boxplot(x='Species', y = 'Petal.Length', data=df)
plt.show()

# %%
fig, ax = plt.subplots()
fig.set_size_inches(8, 6)
sns.boxplot(x='Species', y = 'Petal.Width', data=df)
plt.show()

# %% [markdown]
# ## Observations
# 1) Most important features are Petal Width and Petal Length
# 2) If we were to choose only one feature for seperation Petal Length would be ideal choice
# 2) Setosa can be easily distinguished

# %% [markdown]
# ## Conditions program

# %%
petal_length = float(input("Input Petal Length: "))

if petal_length <= 2.1 :
    print("Flower is Setosa")
elif petal_length >=2.1 and petal_length <=4.8:
    print("Flower is Versicolor")
elif petal_length > 4.8:
    print("Flower is Virginica")
# Out:
# Input Petal Length:  4.9
# Flower is Virginica
